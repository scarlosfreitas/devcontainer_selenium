# %%
import os
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 import os
# ----> 2 from selenium import webdriver
#       3 from selenium.webdriver.chrome.service import Service
#       4 from selenium.webdriver.chrome.options import Options
#
# ModuleNotFoundError: No module named 'selenium'

# %%
from langchain_openai import ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import JsonOutputParser

# %%
# Configuração do Selenium (Headless = Sem abrir janela visual)
chrome_options = Options()
# chrome_options.add_argument("--headless")

driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

driver.get('teste')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 # Configuração do Selenium (Headless = Sem abrir janela visual)
# ----> 2 chrome_options = Options()
#       3 # chrome_options.add_argument("--headless")
#       5 driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)
#
# NameError: name 'Options' is not defined

# %%
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import os

chrome_options = Options()
# IMPORTANTE: Não use --headless
chrome_options.add_argument("--no-sandbox")
chrome_options.add_argument("--disable-dev-shm-usage")

# Define o display caso não esteja nas variáveis de ambiente
os.environ["DISPLAY"] = ":1"

driver = webdriver.Chrome(options=chrome_options)
driver.get("https://www.google.com")
# Out:
# ---------------------------------------------------------------------------
# SessionNotCreatedException                Traceback (most recent call last)
# Cell In[1], line 13
#      10 # Define o display caso não esteja nas variáveis de ambiente
#      11 os.environ["DISPLAY"] = ":1"
# ---> 13 driver = webdriver.Chrome(options=chrome_options)
#      14 driver.get("https://www.google.com")
#
# File /workspace/.venv/lib/python3.13/site-packages/selenium/webdriver/chrome/webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# File /workspace/.venv/lib/python3.13/site-packages/selenium/webdriver/chromium/webdriver.py:66, in ChromiumDriver.__init__(self, browser_name, vendor_prefix, options, service, keep_alive)
#      57 executor = ChromiumRemoteConnection(
#      58     remote_server_addr=self.service.service_url,
#      59     browser_name=browser_name,
#    (...)     62     ignore_proxy=self.options._ignore_local_proxy,
#      63 )
#      65 try:
# ---> 66     super().__init__(command_executor=executor, options=self.options)
#      67 except Exception:
#      68     self.quit()
#
# File /workspace/.venv/lib/python3.13/site-packages/selenium/webdriver/common/webdriver.py:25, in LocalWebDriver.__init__(self, *args, **kwargs)
#      24 def __init__(self, *args, **kwargs):
# ---> 25     super().__init__(*args, **kwargs)
#      26     self._is_remote = False
#
# File /workspace/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py:271, in WebDriver.__init__(self, command_executor, keep_alive, file_detector, options, locator_converter, web_element_cls, client_config)
#     269 self._authenticator_id = None
#     270 self.start_client()
# --> 271 self.start_session(capabilities)
#     272 self._fedcm = FedCM(self)
#     274 self._websocket_connection: WebSocketConnection | None = None
#
# File /workspace/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py:366, in WebDriver.start_session(self, capabilities)
#     364 caps = _create_caps(capabilities)
#     365 try:
# --> 366     response = self.execute(Command.NEW_SESSION, caps)["value"]
#     367     self.session_id = response.get("sessionId")
#     368     self.caps = response.get("capabilities")
#
# File /workspace/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/webdriver.py:446, in WebDriver.execute(self, driver_command, params)
#     443 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     445 if response:
# --> 446     self.error_handler.check_response(response)
#     447     response["value"] = self._unwrap_value(response.get("value", None))
#     448     return response
#
# File /workspace/.venv/lib/python3.13/site-packages/selenium/webdriver/remote/errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# SessionNotCreatedException: Message: session not created: Chrome instance exited. Examine ChromeDriver verbose log to determine the cause.; For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#sessionnotcreatedexception
# Stacktrace:
# #0 0x6116b80c2eea <unknown>
# #1 0x6116b7ad1ae5 <unknown>
# #2 0x6116b7b0e69b <unknown>
# #3 0x6116b7b09369 <unknown>
# #4 0x6116b7b5957e <unknown>
# #5 0x6116b7b58c6c <unknown>
# #6 0x6116b7b17cef <unknown>
# #7 0x6116b7b18ab1 <unknown>
# #8 0x6116b8087d64 <unknown>
# #9 0x6116b808ac51 <unknown>
# #10 0x6116b8074b6a <unknown>
# #11 0x6116b808b81e <unknown>
# #12 0x6116b805b6e0 <unknown>
# #13 0x6116b80afb18 <unknown>
# #14 0x6116b80afce8 <unknown>
# #15 0x6116b80c192e <unknown>
# #16 0x7f73aa90caa4 <unknown>
# #17 0x7f73aa999a64 __clone
